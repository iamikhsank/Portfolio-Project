# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
# Written Report :
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# ### Written Report
#
# ---
#
# #### 1. Data Validation
#
# In the initial phase, data validation was conducted to ensure data quality aligns with analytical needs. The following steps were performed:
#
# - **Shape Check**: The data’s shape was checked to verify the number of rows and columns, ensuring the data quantity met expectations and revealed no anomalies.
#
# - **Data Type Verification**: Each column was inspected to ensure the data type was appropriate. Numeric and categorical columns were verified to align with their respective attributes.
#
# - **Column Names**: Column names were checked and adjusted for consistency, ensuring each column’s label was clear and straightforward for further analysis.
#
# - **Data Duplication**: Duplicate data entries, particularly in the `Customer_ID` column, were checked to ensure no customer entries were repeated. No significant duplication was found after validation.
#
# - **Missing Values**: Each column was checked for missing values. In the `revenue` column, missing values were filled with the average revenue per `sales_method` category to minimize bias from missing values.
#
# #### 2. Data Standardization
#
# 1. Standardization Format and Cleaning
# Standardization was performed to align the data format in the sales_method column and to cap extreme values in the years_as_customer column. The following steps were applied:
#
#    Sales Method Standardization:
#
#    - The symbol + was replaced with & to ensure consistency in the formatting.
#    - Variants like em + call were standardized to Email + Call.
#    - All entries labeled email were reformatted to capitalize the first letter, becoming Email.
#    - The variant em & call was adjusted to Email & Call.
#    - This step ensured that each entry in the sales_method column was formatted consistently, which          facilitates easier analysis and segmentation.
#
#
#    Years as Customer Capping:
#
#    - A maximum cap was set for the years_as_customer column at 39 years. Any values exceeding this          limit were set to 39. This measure was taken to eliminate outliers that could skew analysis            results and because the value does not match the existing year data.
#
#
#
# 2. Missing Value Imputation
# In the revenue column, some values were missing. These missing values were filled using the average revenue based on each sales_method category. Imputing missing values using the average from each category helps maintain data integrity and reduce potential bias caused by missing entries.
# The Python code for this missing value imputation is as follows:
# `df['revenue'].fillna(df.groupby('sales_method')['revenue'].transform('mean').round(2))
# `
#
# With these data cleaning steps, the dataset becomes more analysis-ready, improving the quality of data used and ensuring that patterns derived from the analysis are more accurate and reliable.
# The data cleaning process involved two key steps:
# Standardization and missing value imputation. In the standardization step, entries in the sales_method column were standardized for consistency, and extreme values in years_as_customer were capped at 39 to reduce outlier impact. In the missing value imputation step, missing revenue values were filled using the mean revenue for each sales_method category, preserving data quality and reducing bias from missing entries. These steps prepared the dataset for reliable and accurate analysis.
#
# #### 3. Exploratory Data Analysis (EDA)
#
# The EDA phase aimed to understand data characteristics through visualization and distribution analysis.
#
# - **Histograms for Integer Columns**: Histograms were created for all integer columns to show the frequency distribution within each column. This helped identify distribution patterns and any potential outliers.
#
# - **Boxplots for Integer Columns**: Boxplots were created for all integer columns to help identify outliers and understand data spread.
#
# - **Pairplot**: A pairplot was used to display relationships among integer variables in the dataset, aiding in analyzing correlations and potential patterns among variables.
#
# ---
#
# 1.   Call Method
#
#   *   **Week 1 to 4** : Revenue increases slowly but consistently week by week, showing a stable trend.
#   *   **Week 4 to 5** : There's a small revenue peak, indicating a slight uptick in the effectiveness of the Call method during this period.
#   *   **Week 5 to 6** : Revenue slightly decreases in the final week, which might indicate stagnation or a drop in the effectiveness of the Call strategy.
#
#   Conclusion for Call Method :
#
#   The Call method shows slow and steady revenue growth but tends to stagnate or slightly decline in the last week. This suggests that while it may be beneficial for long-term use, it might need additional strategies to maintain momentum.
#
# 2.   Email Method
#
#   *   **Week 1 to 2** : Revenue from Email is very high in the first week but then drops sharply by the second week.
#   *   **Week 2 to 4** : After the initial drop, revenue continues to decline slowly, reaching its lowest point by week 4, indicating waning interest or effectiveness.
#   *   **Week 4 to 6** : Revenue further declines sharply in weeks 5 and 6, showing that the Email method might lose effectiveness quickly.
#
#   Conclusion for Email Method :
#
#   The Email method has high potential for generating revenue initially but declines sharply afterward. This suggests that while it can boost revenue in the short term, it may not be suitable for sustained revenue growth over time.
#
#
# 3.   Email & Call Method
#
#   *   **Week 1 to 4** : Revenue experiences a very rapid and significant increase from the first to the fourth week. This trend indicates that the combination of Email & Call is more effective at attracting and retaining customer interest.
#   *   **Week 4 to 6** : Although there is a decline in the final week, revenue remains high compared to the other two methods, showing that Email & Call is the most effective approach for generating revenue.
#
#   Conclusion for Email & Call Method:
#
#   The combination of Email & Call yields fast and consistent revenue growth, with a peak at week 4. Despite the decline in the final weeks, this method still performs significantly better than Call or Email alone.
#
# ---
#
# *   **Short-Term** : For quick results, the Email method can be used as it generates high revenue initially, but it should be accompanied by additional strategies to sustain its impact.
# *   **Long-Term** : The Call method can be maintained, but it requires enhancement with supplementary strategies to prevent stagnation in later weeks.
# *   **Primary Method** : The Email & Call combination is the most effective strategy overall. I recommend prioritizing this method for long-term use, as it delivers consistent and substantial revenue growth.
#
# *   **Advice** : Based on these findings, the company should prioritize the Email & Call combination as the primary strategy to sustain and increase revenue.
# #### 4. Defining Business Metrics to Track Performance
#
# The metric used to monitor business performance is:
#
# - **Average Revenue per Customer Sales Effort**
#   This metric tracks the average revenue generated from each sales effort directed at a customer. It assists the business in assessing the effectiveness of each sales approach in generating revenue and identifying the most profitable sales methods.
#
#   - **Usage**: The business can use this metric to monitor sales effectiveness across various methods (`sales_method`). This allows for evaluating sales strategies with potential to enhance revenue.
#
#   - **Initial Value Estimate**: Based on current data, the average revenue per sales effort per customer was calculated and can be used as a benchmark for initial performance.
#
#   - To get a better understanding of the performance of each sales method I create a metric called Average Reveue per Customer Sales Effort(ARPSE). This metric takes into account the difficulty of each sales method in terms of time spent with email having a value of 0.5, email & call 1 and call 3.
#
#   - The ARCPSE results show that Email has the highest value with 194.25, followed by Email & Call with 183.65 and finally call with 15.86. This suggests that the call method is the most efficient in terms of reveneue generated per unit of effort.
#
# However, it is important to note that additional factors have been observed. The 'Email & Call' method had customers with more website visits and higher average number of items purchased. Moreover, this method demonstrated a steady increase in revenue growth over the six-week period. In contrast, the 'Call' method showed high revenue in week 1 but decreased over time.
#
# #### 5. Final Summary and Recommendations
#
# Based on the analysis and data exploration findings, here are some business recommendations:
#
# 1. **Optimize Sales Strategy Based on `sales_method`**: Using the `Average Revenue per Customer Sales Effort` metric, the business can evaluate the most effective sales methods and allocate more resources to strategies with higher profitability.
#
# 2. **Data Input and Standardization Improvements**: Analysis findings show that input corrections in the `sales_method` column improve data quality, supporting more accurate analysis. Therefore, implementing stricter data entry policies will help maintain data quality in the future.
#
# 3. **Customer Segmentation**: Analysis of `revenue` distribution suggests a potential for customer segmentation based on average revenue generated by each sales method. This strategy can help increase the personalization and effectiveness of marketing campaigns.
#
# 4. Taking in all factors from the analysis it is recommended to focus on the Email & Call method for the following reasons:
#
# While 'Email' has the highest ARCPSE, the 'Email & Call' method generates more customer engagement, as evidenced by higher website visits and average items purchased. This could lead to stronger customer relationships and long-term growth. The 'Email & Call' method has shown a consistent upward trend in revenue generation over six weeks, indicating its potential for continued success. The 'Call' method is the least efficient in terms of effort and revenue generation and has a downward trend in revenue over time. In conclusion, the 'Email & Call' method should be prioritized for sales efforts, as it demonstrates better customer engagement, consistent revenue growth, and a more sustainable balance between effort and return.
#
# In summary, the application of performance sales metrics and the evaluation of sales methods based on this data are expected to enhance business efficiency and profitability.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('product_sales.csv', sep=',')

# %%
df.head()
# Out:
#    week  sales_method  ... nb_site_visits      state
# 0     2         Email  ...             24    Arizona
# 1     6  Email + Call  ...             28     Kansas
# 2     5          Call  ...             26  Wisconsin
# 3     4         Email  ...             25    Indiana
# 4     3         Email  ...             28   Illinois
#
# [5 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['week', 'sales_method', 'customer_id', 'nb_sold', 'revenue',
#        'years_as_customer', 'nb_site_visits', 'state'],
#       dtype='object')

# %%
df.shape
# Out:
# (15000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %%
df.describe(include='all')
# Out:
#                 week sales_method  ... nb_site_visits       state
# count   15000.000000        15000  ...   15000.000000       15000
# unique           NaN            5  ...            NaN          50
# top              NaN        Email  ...            NaN  California
# freq             NaN         7456  ...            NaN        1872
# mean        3.098267          NaN  ...      24.990867         NaN
# std         1.656420          NaN  ...       3.500914         NaN
# min         1.000000          NaN  ...      12.000000         NaN
# 25%         2.000000          NaN  ...      23.000000         NaN
# 50%         3.000000          NaN  ...      25.000000         NaN
# 75%         5.000000          NaN  ...      27.000000         NaN
# max         6.000000          NaN  ...      41.000000         NaN
#
# [11 rows x 8 columns]

# %%
# Frequency
for col in df.columns:
  print(df[col].value_counts())
  print('\n----------------------\n')
# Out:
# 1    3721
# 4    2575
# 5    2574
# 2    2491
# 3    2411
# 6    1228
# Name: week, dtype: int64
#
# ----------------------
#
# Email           7456
# Call            4962
# Email + Call    2549
# em + call         23
# email             10
# Name: sales_method, dtype: int64
#
# ----------------------
#
# 2e72d641-95ac-497b-bbf8-4861764a7097    1
# e0c955c5-50b4-43dc-bfdd-e181ac3c8e50    1
# 8a7a36dd-8fdc-4d08-b87d-4f1548f723be    1
# f7c7fcbe-ac44-4e62-a470-b04eb19fb5a1    1
# 9149e07e-cd2f-4a94-a97b-2f2f475afdbb    1
#                                        ..
# c1779213-7d49-494b-9aec-f488290bff5a    1
# 16d14cab-0900-4759-9c18-8569dae8c711    1
# 3cd54608-5e34-4340-976e-61725b41d175    1
# ede3a4b7-94bf-46b2-8bd2-55e009b7c0a9    1
# 4e077235-7c17-4054-9997-7a890336a214    1
# Name: customer_id, Length: 15000, dtype: int64
#
# ----------------------
#
# 10    3677
# 9     3535
# 11    2439
# 8     1941
# 12    1088
# 13     939
# 7      698
# 15     555
# 14      97
# 16      31
# ...

# %% [markdown]
# ## **Cleaning and Standardizing Data**
# The data was standardized into a uniform format, ensuring consistency across each value.
# and Input errors were corrected in the sales_method column to maintain data integrity, consolidating variations of identical values to be consistent.

# %% [markdown]
# Standardization was performed to align the data format in the sales_method column and to cap extreme values in the years_as_customer column. The following steps were applied:
#
# Sales Method Standardization:
#
# The symbol + was replaced with & to ensure consistency in the formatting.
# Variants like em + call were standardized to Email + Call.
# All entries labeled email were reformatted to capitalize the first letter, becoming Email.
# The variant em & call was adjusted to Email & Call.
# This step ensured that each entry in the sales_method column was formatted consistently, which facilitates easier analysis and segmentation.
#
# Years as Customer Capping:
#
# A maximum cap was set for the years_as_customer column at 39 years. Any values exceeding this limit were set to 39. This measure was taken to eliminate outliers that could skew analysis results.

# %%
# data cleaning and Standardizing
def standardizing(df):
  # sales method
  df['sales_method'] = df['sales_method'].str.replace('+','&')
  df['sales_method'] = df['sales_method'].str.replace('em + call','Email + Call')
  df['sales_method'] = df['sales_method'].str.replace('email','Email')
  df['sales_method'] = df['sales_method'].str.replace('em & call','Email & Call')
  df.loc[df['years_as_customer'] > 39,'years_as_customer'] = 39
  return df

# %%
df['sales_method'] = df['sales_method'].str.replace('em & call','Email & Call')

# %%
df = standardizing(df)

# %% [markdown]
# ## Missing Value Imputation
# In the revenue column, some values were missing. These missing values were filled using the average revenue based on each sales_method category. Imputing missing values using the average from each category helps maintain data integrity and reduce potential bias caused by missing entries.

# %%
# find missing values
df.isna().sum()
# Out:
# week                    0
# sales_method            0
# customer_id             0
# nb_sold                 0
# revenue              1074
# years_as_customer       0
# nb_site_visits          0
# state                   0
# dtype: int64

# %%
# find revenue mean per sales method before we filled it with mean per method
df.groupby('sales_method')['revenue'].mean()
# Out:
# sales_method
# Call             47.597467
# Email            97.127684
# Email & Call    183.651233
# Name: revenue, dtype: float64

# %%
# filling data
def fill(df):
  df['revenue'] = df['revenue'].fillna(df.groupby('sales_method')['revenue'].transform('mean').round(2))
  return df

# %%
df = fill(df)

# %%
clean_df = df.copy()

# %%
# Exploratory Data Analysis
# See the distribution with Histogram
for col in clean_df.select_dtypes(include='number'):
  sns.histplot(clean_df[col], kde=True)
  plt.show()
  print('\n')

# %%
# Boxplot
for b in df.select_dtypes(include='number'):
  plt.figure(figsize=(6,2))
  sns.boxplot(x=df[b])
  plt.show()
  print('\n')

# %%
# Pairplot
sns.pairplot(clean_df, hue='sales_method')

# %% [markdown]
# ## Q1 : How many customers were there for each approach?

# %%
# Total Customers per Sales Method
customer_per_sales_method = clean_df['sales_method'].value_counts()
customer_per_sales_method
# Out:
# Email           7466
# Call            4962
# Email & Call    2572
# Name: sales_method, dtype: int64

# %%
ax = sns.barplot(x=customer_per_sales_method.index, y=customer_per_sales_method.values, hue=customer_per_sales_method.index, palette='crest')

for l in ax.containers:
  ax.bar_label(l)

plt.title('Total Customers per Sales Method')
plt.xlabel('Sales Method')
plt.show()

# %% [markdown]
# ## Q2 : What does the spread of the revenue look like overall? And for each method?

# %%
# Spread of revenue with Boxplot

plt.figure(figsize=(8,2))
sns.boxplot(data=clean_df,x='revenue',fliersize=5,palette='crest')
plt.xlabel('Revenue')
plt.title('Spread of Overall Revenue')
plt.show()

# %%
# Spread of revenue per each method
plt.figure(figsize=(10,4))
sns.boxplot(data=clean_df, x='revenue', hue='sales_method',fliersize=4) 
plt.legend(bbox_to_anchor=(1.,1), loc='upper left')
plt.title('Spread of Revenue per each method')
plt.show()

# %% [markdown]
# ## Q3 : Was there any difference in revenue over time for each of the methods?

# %%
revenue_overtime = clean_df.groupby(['week','sales_method'])['revenue'].sum().unstack()
revenue_overtime.style.background_gradient(cmap='crest')
# Out:
# <style type="text/css">
# #T_916ae_row0_col0, #T_916ae_row0_col2, #T_916ae_row5_col1 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_916ae_row0_col1, #T_916ae_row4_col0, #T_916ae_row4_col2 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_916ae_row1_col0 {
#   background-color: #58a590;
#   color: #f1f1f1;
# }
# #T_916ae_row1_col1 {
#   background-color: #2b7d8c;
#   color: #f1f1f1;
# }
# #T_916ae_row1_col2 {
#   background-color: #8bc191;
#   color: #000000;
# }
# #T_916ae_row2_col0 {
#   background-color: #47978f;
#   color: #f1f1f1;
# }
# #T_916ae_row2_col1 {
#   background-color: #4a9a8f;
#   color: #f1f1f1;
# }
# #T_916ae_row2_col2 {
#   background-color: #5ba790;
#   color: #f1f1f1;
# }
# #T_916ae_row3_col0 {
#   background-color: #26497e;
#   color: #f1f1f1;
# }
# #T_916ae_row3_col1 {
#   background-color: #43938f;
#   color: #f1f1f1;
# }
# #T_916ae_row3_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# #T_916ae_row4_col1 {
# ...

# %%
sns.lineplot(data=revenue_overtime, linewidth=2.5)
plt.legend(bbox_to_anchor=(1.,1), loc='upper left')
plt.title('Revenue Overtime')
plt.xlabel('Week')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ## Q4 : Based on the data, which method would you recommend we continue to use? Some of these methods take more time from the team so they may not be the best for us to use if the results are similar.

# %% [markdown]
# 1.   Call Method
#
#   *   **Week 1 to 4** : Revenue increases slowly but consistently week by week, showing a stable trend.
#   *   **Week 4 to 5** : There's a small revenue peak, indicating a slight uptick in the effectiveness of the Call method during this period.
#   *   **Week 5 to 6** : Revenue slightly decreases in the final week, which might indicate stagnation or a drop in the effectiveness of the Call strategy.
#
#   Conclusion for Call Method :
#
#   The Call method shows slow and steady revenue growth but tends to stagnate or slightly decline in the last week. This suggests that while it may be beneficial for long-term use, it might need additional strategies to maintain momentum.
#
# 2.   Email Method
#
#   *   **Week 1 to 2** : Revenue from Email is very high in the first week but then drops sharply by the second week.
#   *   **Week 2 to 4** : After the initial drop, revenue continues to decline slowly, reaching its lowest point by week 4, indicating waning interest or effectiveness.
#   *   **Week 4 to 6** : Revenue further declines sharply in weeks 5 and 6, showing that the Email method might lose effectiveness quickly.
#
#   Conclusion for Email Method :
#
#   The Email method has high potential for generating revenue initially but declines sharply afterward. This suggests that while it can boost revenue in the short term, it may not be suitable for sustained revenue growth over time.
#
#
# 3.   Email & Call Method
#
#   *   **Week 1 to 4** : Revenue experiences a very rapid and significant increase from the first to the fourth week. This trend indicates that the combination of Email & Call is more effective at attracting and retaining customer interest.
#   *   **Week 4 to 6** : Although there is a decline in the final week, revenue remains high compared to the other two methods, showing that Email & Call is the most effective approach for generating revenue.
#
#   Conclusion for Email & Call Method:
#
#   The combination of Email & Call yields fast and consistent revenue growth, with a peak at week 4. Despite the decline in the final weeks, this method still performs significantly better than Call or Email alone.

# %% [markdown]
# ## Optional : Investigating other differences between customers in each group

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=clean_df, x='sales_method',y='years_as_customer',hue='sales_method')

plt.xlabel('Sales Method')
plt.ylabel('Years as Customer')
plt.title('Boxplot of Years as Customer per Sales Method')
plt.show()

# %%
sns.boxplot(data=clean_df, x='sales_method',y='nb_sold',hue='sales_method')
plt.xlabel('Sales Method')
plt.ylabel('Age')
plt.title('Number of Sold per Sales Method')
# Out:
# Text(0.5, 1.0, 'Number of Sold per Sales Method')

# %%
sns.boxplot(data=clean_df, x='sales_method',y='nb_site_visits',hue='sales_method')
plt.xlabel('Sales Method')
plt.ylabel('Age')
plt.title('Number of Sites Visits per Sales Method')
# Out:
# Text(0.5, 1.0, 'Number of Sites Visits per Sales Method')

# %%
grouped = clean_df.groupby(['week','sales_method']).agg({'revenue':'sum', 'customer_id':'count'})
grouped['average_revenue_per_customer'] = grouped['revenue'] / grouped['customer_id']
grouped.style.background_gradient(cmap='crest')
# Out:
# <style type="text/css">
# #T_6f5ad_row0_col0 {
#   background-color: #9dc991;
#   color: #000000;
# }
# #T_6f5ad_row0_col1 {
#   background-color: #66ae90;
#   color: #f1f1f1;
# }
# #T_6f5ad_row0_col2, #T_6f5ad_row2_col0, #T_6f5ad_row2_col1 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_6f5ad_row1_col0, #T_6f5ad_row1_col1, #T_6f5ad_row17_col2 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_6f5ad_row1_col2, #T_6f5ad_row6_col1 {
#   background-color: #5aa690;
#   color: #f1f1f1;
# }
# #T_6f5ad_row2_col2 {
#   background-color: #2d808c;
#   color: #f1f1f1;
# }
# #T_6f5ad_row3_col0 {
#   background-color: #92c491;
#   color: #000000;
# }
# #T_6f5ad_row3_col1 {
#   background-color: #62ab90;
#   color: #f1f1f1;
# }
# #T_6f5ad_row3_col2 {
#   background-color: #99c791;
#   color: #000000;
# }
# #T_6f5ad_row4_col0 {
#   background-color: #297b8c;
#   color: #f1f1f1;
# }
# #T_6f5ad_row4_col1, #T_6f5ad_row16_col2 {
#   background-color: #33858d;
# ...

# %%
pivot = grouped.pivot_table(index='week',columns='sales_method',values='average_revenue_per_customer')
pivot.style.background_gradient(cmap='crest')
# Out:
# <style type="text/css">
# #T_1ad10_row0_col0, #T_1ad10_row0_col1, #T_1ad10_row0_col2 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_1ad10_row1_col0 {
#   background-color: #5ba790;
#   color: #f1f1f1;
# }
# #T_1ad10_row1_col1 {
#   background-color: #57a490;
#   color: #f1f1f1;
# }
# #T_1ad10_row1_col2 {
#   background-color: #5ca890;
#   color: #f1f1f1;
# }
# #T_1ad10_row2_col0 {
#   background-color: #6ab090;
#   color: #f1f1f1;
# }
# #T_1ad10_row2_col1 {
#   background-color: #82bc91;
#   color: #000000;
# }
# #T_1ad10_row2_col2 {
#   background-color: #69b090;
#   color: #f1f1f1;
# }
# #T_1ad10_row3_col0 {
#   background-color: #2f818d;
#   color: #f1f1f1;
# }
# #T_1ad10_row3_col1, #T_1ad10_row4_col1 {
#   background-color: #35868d;
#   color: #f1f1f1;
# }
# #T_1ad10_row3_col2 {
#   background-color: #2d808c;
#   color: #f1f1f1;
# }
# #T_1ad10_row4_col0 {
#   background-color: #26788c;
#   color: #f1f1f1;
# }
# #T_1ad10_row4_col2 {
#   background-color: #23758b;
# ...

# %%
sns.lineplot(data=pivot,linewidth=2.5,marker='o')
plt.legend(bbox_to_anchor=(1.,1), loc='upper left')
plt.title('Average Revenue per Customer Over Time  by Method')
plt.xlabel('Week')
plt.ylabel('Average Revenue per Customer')
plt.show()

# %% [markdown]
# ## Defining Business Metrics to Track Performance - Average Revenue per Customer Sales Effort

# %% [markdown]
# To get a better understanding of the performance of each sales method I create a metric called Average Reveue per Customer Sales Effort(ARPSE). This metric takes into account the difficulty of each sales method in terms of time spent with email having a value of 0.5, email + call 1 and call 3.

# %%
# Define the sales effort for each sales method
sales_effort = {
    'Email': 0.5,
    'Call': 3,
    'Email & Call': 1}

grouped_df = clean_df.groupby(['sales_method']).agg({'revenue':'sum','customer_id':'count'}).reset_index()

# Calculate ARCPSE for each sales method
grouped_df['ARPSE'] = grouped_df.apply(lambda row: row['revenue'] / (row['customer_id'] * sales_effort[row['sales_method']]), axis=1)

# %%
grouped_df[['sales_method','ARPSE']].style.background_gradient(cmap='crest')
# Out:
# <style type="text/css">
# #T_acab6_row0_col1 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_acab6_row1_col1 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_acab6_row2_col1 {
#   background-color: #2a3c77;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_acab6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acab6_level0_col0" class="col_heading level0 col0" >sales_method</th>
#       <th id="T_acab6_level0_col1" class="col_heading level0 col1" >ARPSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acab6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acab6_row0_col0" class="data row0 col0" >Call</td>
#       <td id="T_acab6_row0_col1" class="data row0 col1" >15.865853</td>
#     </tr>
#     <tr>
#       <th id="T_acab6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acab6_row1_col0" class="data row1 col0" >Email</td>
# ...

# %% [markdown]
# The ARCPSE results show that Email has the highest value with 194.25, followed by Email & Call with 183.65 and finally call with 15.86. This suggests that the call method is the most efficient in terms of reveneue generated per unit of effort.
#
# However, it is important to note that additional factors have been observed. The 'Email + Call' method had customers with more website visits and higher average number of items purchased. Moreover, this method demonstrated a steady increase in revenue growth over the six-week period. In contrast, the 'Call' method showed high revenue in week 1 but decreased over time.

# %% [markdown]
# ## Conclusion and Recommendations
#
# ---
#
#
# Taking in all factors from the analysis it is recommended to focus on the Email & Call method for the following reasons:
#
# While 'Email' has the highest ARCPSE, the 'Email & Call' method generates more customer engagement, as evidenced by higher website visits and average items purchased. This could lead to stronger customer relationships and long-term growth.
# The 'Email & Call' method has shown a consistent upward trend in revenue generation over six weeks, indicating its potential for continued success.
# The 'Call' method is the least efficient in terms of effort and revenue generation and has a downward trend in revenue over time. In conclusion, the 'Email & Call' method should be prioritized for sales efforts, as it demonstrates better customer engagement, consistent revenue growth, and a more sustainable balance between effort and return.
